# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
s=pd.read_csv("Iris.csv")
p=s.replace({'Species':{'Iris-setosa':1,'Iris-virginica':2,'Iris-versicolor':3}})
p
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        1
# 1      2            4.9           3.0            1.4           0.2        1
# 2      3            4.7           3.2            1.3           0.2        1
# 3      4            4.6           3.1            1.5           0.2        1
# 4      5            5.0           3.6            1.4           0.2        1
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
sns.set_style('whitegrid')
sns.FacetGrid(s,hue='Species').map(plt.scatter,'SepalLengthCm','SepalWidthCm').add_legend()
plt.show()

# %%
X=p[["SepalWidthCm","SepalLengthCm","PetalLengthCm","PetalWidthCm"]]
Y=p["Species"]

# %%
from sklearn.model_selection import train_test_split
xe,xt,ye,yt=train_test_split(X,Y,test_size=0.32,random_state=40)

# %%
from sklearn.tree import DecisionTreeClassifier
i=DecisionTreeClassifier(criterion='gini',max_depth=5)
d.fit(xe,ye)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
from sklearn import tree
tree.plot_tree(d)
plt.show()
